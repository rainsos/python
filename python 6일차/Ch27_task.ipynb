# %% [markdown]
# 두 숫자를 더하는 람다 함수를 작성하고, 이를 변수에 할당한 후 사용하세요.

# %%
# lamda 함수적용
add = lambda a, b: a + b

result = add(10, 20)
print("합계:", result)
# Out:
# 합계: 30

# %%
# def 적용시

def add(a, b):
    return a + b

print(add(10, 20))
# Out:
# 30
