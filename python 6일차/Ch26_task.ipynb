# %% [markdown]
# 0부터 시작하여 n까지의 숫자 중에서 홀수만 생성하는 제너레이터 odd_numbers를 작성하세요.

# %%
def odd_numbers(n: int):
    for i in range(n + 1):  # n + 1 적용해야 n까지 적용
        if i % 2 != 0:
            yield i


for number in odd_numbers(10): # for문 자체에 next가적용되어있다.
    print(number)
