# %% [markdown]
# 팩토리얼을 계산하는 재귀 함수 factorial을 작성하세요.

# %%
def factorial(n: int) -> int:

    if n == 0 or n == 1: # 시안성,불필요한 호출방지
        return 1

    return n * factorial(n - 1)


print(factorial(5))
print(factorial(1))
print(factorial(0))
# Out:
# 120
# 1
# 1
