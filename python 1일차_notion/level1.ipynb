# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~!
#
# "Challenge : 사칙연산을 이용해 문제 풀기"는 잘 풀어보셨나요?
#
#
# 너~~무 어려웠어요! 하는 분들을 위해 만들어봤습니다!
#
# 문제 도장깨기 !!!!!
#
# 차근차근 풀어나가면 파이썬 정복 가능입니다!
#
# 화이팅 !
#
#
# Chapter04의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br>
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>
# <br>

# %% [markdown]
# -----

# %% [markdown]
# <br>
#
# __[문제1]__
#
# 한 상자에 사과가 7개 들어있습니다.
#
# 사과가 많이 먹고 싶어서 3개의 상자를 구입했습니다!
#
# 총 사과의 개수를 계산해주세요.
#
#
# <br>

# %%
print (7 * 3)
# Out:
# 21

# %%
# 사과 갯수
apple = 7

# 박스 갯수
box = 3

# 토탈
total = apple * box

# 출력
print (f"사과의 갯수: {total}개")
# Out:
# 사과의 갯수: 21개

# %% [markdown]
# <br>
#
# __[문제2]__
#
# 영화 티켓 한 장의 가격은 10,000원입니다.
#
# 친구 한명이 로또에 당첨되서 티켓을 사준다고 합니다!
#
# 4명의 친구가 각각 4장씩 구매할 때, 총 가격이 어떻게 되는지 계산해주세요
#
# <br>

# %%
print (10000 * 4 * 4)
# Out:
# 160000

# %%
# 영화 티켓 가격
tiket = 10000

# 친구 및 티겟 장수
friends = 4
tikets = 4

#총 가격

total = tiket * friends * tikets

# 출력

print (f"총 {total} 원"
)
# Out:
# 총 160000 원

# %% [markdown]
# <br>
#
# __[문제3]__
#
# 지각입니다 !!!!!
#
# 지하철을 타고 5개의 역이 남았습니다.
#
# 각 역은 3분씩 걸립니다. 시간을 계산해볼 수 있도록 5개의 역을 지나는데 걸린 총 시간을 구해주세요.

# %%
print (5 * 3)
# Out:
# 15

# %%
left = 5  # 남은 역 개수
time = 3  # 한 역당 걸리는 시간 (분)

total_time = left * time

print (str(5 * 3) + "분")
# Out:
# 15분

# %% [markdown]
# <br>__[문제4]__
#
# 파이썬 기초 관련 책이 9권 있습니다.
#
# 오즈코딩스쿨을 통해 파이썬을 마스터 해버려서 필요없습니다.
#
# 책을 3명의 친구에게 똑같이 나눠줄 때, 각 사람에게 몇 권씩 나누어줄 수 있을까요?

# %%
print (str(9 // 3) + "권")
# Out:
# 3권

# %%
total_books = 9  # 책 총 권 수
friends = 3  # 친구 수

book = total_books // friends

print (f"{book} 권")
# Out:
# 3 권

# %% [markdown]
# __[문제5]__
#
# 무인도에 2명의 갇혀있습니다.
#
# 가진건 초콜릿 8개뿐,,
#
# 각 사람은 초콜릿을 몇 개씩 먹을 수 있을까요?

# %%
print (8 //2 )
# Out:
# 4

# %%
chocolates = 8  # 총 초콜릿 개수
people = 2  # 사람 수

person = chocolates // people
print (f"{person} 개")
# Out:
# 4 개
